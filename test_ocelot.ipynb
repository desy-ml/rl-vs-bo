# %%
from gym.wrappers import TimeLimit

from environments.ocelot import ARESEAOcelot
# Out:
# initializing ocelot...

# %%
env = ARESEAOcelot()
env = TimeLimit(env, max_episode_steps=50)
env
# Out:
# <TimeLimit<ARESEAOcelot instance>>

# %%
env.observation_space
# Out:
# Dict(achieved_goal:Box(-1.0, 1.0, (4,), float32), desired_goal:Box(-1.0, 1.0, (4,), float32), observation:Box(-1.0, 1.0, (6,), float32))

# %%
env.reset()
# Out:
# {'observation': array([ 0.33043   ,  0.73546651, -0.23601144,  0.37803742,  0.05955475,
#          0.07279365]),
#  'desired_goal': array([0.82155275, 0.03587634, 0.07451662, 0.31059965], dtype=float32),
#  'achieved_goal': array([1.07863868, 1.31636131, 2.44873174, 9.39266003])}

# %%
env.goal
# Out:
# array([1.6431055e-03, 7.1752678e-05, 3.7258309e-05, 1.5529983e-04],
#       dtype=float32)

# %%
env.render()

# %%
for _ in range(10):
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    # print(f"{observation[:4]}\t{reward:.5f}\t{done}")

env.render()
