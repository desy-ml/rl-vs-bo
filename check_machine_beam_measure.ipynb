# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import pandas as pd

# %%
df = pd.read_pickle("machine_studies/211209_still_deluge_050_100/still-deluge-998_061_20211210072852.pkl")

# %%
i = 24
plt.figure(figsize=(20,16))
plt.imshow(df.loc[i,"beam_image"], extent=(-0.0040634352,0.0040634352,-0.002495838,0.002495838))
e = Ellipse((df.loc[i,"mu_x"],df.loc[i,"mu_y"]), df.loc[i,"sigma_x"], df.loc[i,"sigma_y"], ls="--", fill=False, color="red")
plt.gca().add_patch(e)
plt.show()
