# %%
from gym.wrappers import TimeLimit

from environments.machine import ARESEAMachine
# Out:
# initializing ocelot...
# WARNING: Diagnostic screen was converted with default screen properties.
# WARNING: Diagnostic screen was converted with default screen properties.

# %%
env = ARESEAMachine()
env = TimeLimit(env, max_episode_steps=50)
env
# Out:
# <TimeLimit<ARESEAMachine instance>>

# %%
env.observation_space
# Out:
# Dict(achieved_goal:Box(-1.0, 1.0, (4,), float32), desired_goal:Box(-1.0, 1.0, (4,), float32), observation:Box(-1.0, 1.0, (6,), float32))

# %%
env.reset()
# Out:
# {'observation': array([1., 0., 0., 0., 0., 0.]),
#  'desired_goal': array([0.07244586, 0.9970862 , 0.07839324, 0.5680962 ], dtype=float32),
#  'achieved_goal': array([-0.0033198 ,  0.0024469 ,  0.28193629,  0.3075509 ])}

# %%
env.goal
# Out:
# array([1.4489173e-04, 1.9941726e-03, 3.9196624e-05, 2.8404812e-04],
#       dtype=float32)

# %%
env.render()

# %%
for _ in range(10):
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    # print(f"{observation[:4]}\t{reward:.5f}\t{done}")

env.render()
